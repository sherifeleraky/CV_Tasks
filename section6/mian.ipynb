# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n-cls.pt")

model.train(data='C:/Users/yousi/OneDrive/Desktop/CV-TASKS-main/Dataset',epochs=20)
# Out:
# New https://pypi.org/project/ultralytics/8.3.44 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40  Python-3.10.0 torch-2.5.1+cpu CPU (AMD Ryzen 5 4600H with Radeon Graphics)
# ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
dataGenerator = ImageDataGenerator(
    rescale = 1/255
)

TestGenerator= dataGenerator.flow_from_directory(directory= 'C:/Users/yousi/OneDrive/Desktop/CV-TASKS-main/Dataset/test',target_size=(176,208),batch_size= 16, class_mode='sparse',shuffle=True)
# Out:
# Found 3543 images belonging to 2 classes.

# %%
# %matplotlib inline

from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

random = next(TestGenerator)

random_image = random[0][0]

random_image = (random_image * 255).astype(np.uint8)

image_PIL = Image.fromarray(random_image)

results = model.predict(source= image_PIL)

predicted = results[0].probs.data


predicted_class = predicted.argmax()

class_name =results[0].names[predicted_class.item()]


plt.imshow(image_PIL.resize((144,144))) 
plt.title(class_name)
plt.show()
# Out:
# 0: 224x224 without_mask 1.00, with_mask 0.00, 7.3ms
# Speed: 8.7ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
