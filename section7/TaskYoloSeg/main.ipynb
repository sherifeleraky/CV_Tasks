# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
model = YOLO("yolo11n-seg.pt") # newer version for better sigmentation

res = model("cat.jpg")  

plt.imshow(res[0].plot())
plt.show()
# Out:
# image 1/1 c:\Users\yousi\OneDrive\Desktop\CV-TASKS-main\section7\TaskYoloSeg\cat.jpg: 640x640 1 cat, 124.4ms
# Speed: 8.1ms preprocess, 124.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
