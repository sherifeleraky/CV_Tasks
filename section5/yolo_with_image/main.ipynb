# %%
from PIL import Image

from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
model = YOLO("yolo11m.pt")

path = "8.jpg"
results = model(source=path,conf=0.4)
# Out:
# image 1/1 c:\Users\yousi\OneDrive\Desktop\CV-TASKS-main\section5\yolo_with_image\8.jpg: 448x640 10 persons, 4 cars, 2 traffic lights, 254.9ms
# Speed: 1.0ms preprocess, 254.9ms inference, 9.7ms postprocess per image at shape (1, 3, 448, 640)

# %%
result_img = results[0].plot()  
plt.imshow(result_img)
plt.axis('off')
plt.show()
